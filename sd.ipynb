# %%
import torch
from diffusers import StableDiffusion3Pipeline

pipe = StableDiffusion3Pipeline.from_pretrained(
    "stabilityai/stable-diffusion-3.5-medium", torch_dtype=torch.bfloat16
)
pipe = pipe.to("cuda")

# Need ~ 13GB VRAM

pipe.enable_model_cpu_offload()

image = pipe(
    "A cat holding a sign that says hello world",
    num_inference_steps=40,
    guidance_scale=4.5,
).images[0]

display(image)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torch
# ----> 2 from diffusers import StableDiffusion3Pipeline
#       4 pipe = StableDiffusion3Pipeline.from_pretrained(
#       5     "stabilityai/stable-diffusion-3.5-medium", torch_dtype=torch.bfloat16
#       6 )
#       7 pipe = pipe.to("cuda")
#
# ModuleNotFoundError: No module named 'diffusers'

# %%
# %pip install --upgrade diffusers
# Out:
# Collecting diffusers
#   Downloading diffusers-0.37.1-py3-none-any.whl.metadata (20 kB)
# Collecting importlib-metadata (from diffusers)
#   Downloading importlib_metadata-9.0.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: filelock in c:\Python312\Lib\site-packages (from diffusers) (3.18.0)
# Requirement already satisfied: httpx<1.0.0 in c:\Python312\Lib\site-packages (from diffusers) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in c:\Python312\Lib\site-packages (from diffusers) (1.7.2)
# Requirement already satisfied: numpy in c:\Python312\Lib\site-packages (from diffusers) (2.1.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\Python312\Lib\site-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in c:\Python312\Lib\site-packages (from diffusers) (2.32.4)
# Requirement already satisfied: safetensors>=0.3.1 in c:\Python312\Lib\site-packages (from diffusers) (0.5.3)
# Requirement already satisfied: Pillow in c:\Python312\Lib\site-packages (from diffusers) (11.3.0)
# Requirement already satisfied: anyio in c:\Python312\Lib\site-packages (from httpx<1.0.0->diffusers) (4.9.0)
# Requirement already satisfied: certifi in c:\Python312\Lib\site-packages (from httpx<1.0.0->diffusers) (2025.7.9)
# Requirement already satisfied: httpcore==1.* in c:\Python312\Lib\site-packages (from httpx<1.0.0->diffusers) (1.0.9)
# Requirement already satisfied: idna in c:\Python312\Lib\site-packages (from httpx<1.0.0->diffusers) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\Python312\Lib\site-packages (from httpcore==1.*->httpx<1.0.0->diffusers) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Python312\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\Python312\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (1.4.2)
# Requirement already satisfied: packaging>=20.9 in c:\Python312\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\Python312\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\Python312\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (4.67.1)
# Requirement already satisfied: typer in c:\Python312\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\Python312\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (4.14.1)
# Requirement already satisfied: colorama in c:\Python312\Lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.34.0->diffusers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\Python312\Lib\site-packages (from anyio->httpx<1.0.0->diffusers) (1.3.1)
# Collecting zipp>=3.20 (from importlib-metadata->diffusers)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Python312\Lib\site-packages (from requests->diffusers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Python312\Lib\site-packages (from requests->diffusers) (2.5.0)
# Requirement already satisfied: click>=8.2.1 in c:\Python312\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Python312\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\Python312\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers) (14.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Python312\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Python312\Lib\site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Python312\Lib\site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\Python312\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers) (0.1.2)
# Downloading diffusers-0.37.1-py3-none-any.whl (5.0 MB)
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    ---------------------------------------- 5.0/5.0 MB 60.8 MB/s  0:00:00
# Downloading importlib_metadata-9.0.0-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, importlib-metadata, diffusers
#
#    ------------- -------------------------- 1/3 [importlib-metadata]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    ---------------------------------------- 3/3 [diffusers]
#
# Successfully installed diffusers-0.37.1 importlib-metadata-9.0.0 zipp-3.23.0
# Note: you may need to restart the kernel to use updated packages.
